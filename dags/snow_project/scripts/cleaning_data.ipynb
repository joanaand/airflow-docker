# %%
import pandas as pd

#file_path = "../data/ski_resorts_list.csv"
#output_path = "../data/ski_resorts_weather_clean.csv"

# %%
#read file
df = pd.read_csv("../data/ski_resorts_weather.csv")

# %%
df[df["resort_name"].str.contains("Serre", case=False, na=False)]
# Out:
#         resort_name country         town  elevation_m  total_km  blue_km  \
# 95  Serre Chevalier  France  Chantemerle       1600.0     250.0    137.5
#
#     red_km  black_km lift_price local_name  ... difficulty_score  \
# 95    80.0      32.5    € 65.50        NaN  ...             1.58
#
#    elevation_band  latitude  longitude  geocode_source  total_snowfall_30d_mm  \
# 95           High  48.61157    3.65927     Chantemerle                    6.3
#
#    avg_snow_depth_30d_mm  avg_temp_30d_c  avg_sunshine_hours_30d  \
# 95              0.000968        2.777419                2.665745
#
#    total_rain_30d_mm
# 95              31.6
#
# [1 rows x 25 columns]

# %%
cdf = pd.read_csv("../data/ski_resorts_clean.csv")

# %%
cdf.head(20)
# Out:
#                                  resort_name      country  \
# 0                                        NaN      Austria
# 1                             Stubai Glacier      Austria
# 2                                Val Gardena        Italy
# 3                                        NaN        Italy
# 4                                        NaN        Italy
# 5                                        NaN      Austria
# 6                                        NaN  Switzerland
# 7                                        NaN      Austria
# 8                                        NaN      Austria
# 9                                   Pfelders        Italy
# 10                             Racines-Giovo        Italy
# 11                                       NaN      Austria
# 12                                       NaN      Austria
# 13                                       NaN      Austria
# 14                                   Sillian      Austria
# 15                                       NaN        Italy
# 16                                 Mayrhofen      Austria
# 17                                       NaN  Switzerland
# 18  Saalbach Hinterglemm Leogang Fieberbrunn      Austria
# 19                                       NaN      Austria
#
#                            town  elevation_m  total_km  blue_km  red_km  \
# 0                   Tauplitzalm       1069.0      43.5     18.5    19.0
# 1         Neustift im Stubaital       1515.0      65.0     38.9    23.2
# 2                    St. Ulrich       1282.0     181.0     52.0   108.0
# 3                      Meransen       1203.0      55.0     18.5    27.2
# 4                     Obereggen        848.0      49.0      9.3    32.8
# 5                       Lermoos       1096.0      26.5     14.4    10.2
# 6                    Bettmeralp       1024.0     104.0     42.0    50.0
# 7            Matrei in Osttirol       1493.0      40.0      8.5    25.5
# 8   Neukirchen am Großvenediger       1330.0      75.0     35.0    30.0
# 9                      Pfelders        901.0      18.0      5.0     9.0
# 10                        Bichl        800.0      28.1      5.6    21.6
# 11                       Ellmau       1249.0     275.0    115.0   121.0
# 12                       Ischgl       1512.0     239.0     47.0   140.0
# 13                        Fügen       1444.0      20.5      5.8    12.0
# 14                      Sillian       1307.0      22.4      5.3    16.1
# 15                     Karersee       1155.0      40.0     19.0    16.2
# 16                    Mayrhofen       1870.0     142.0     44.0    66.0
# 17                       Wengen       1456.0     101.0     33.0    55.0
# 18                     Saalbach       1266.0     270.0    140.0   112.0
# 19                      Nauders       1350.0      75.0     25.0    36.0
#
#     black_km                  lift_price  \
# 0        6.0                      € 59,-
# 1        2.9                     € 72.50
# 2       21.0                      € 80,-
# 3        9.3                      € 70,-
# 4        6.9                      € 71,-
# 5        1.9                      € 68,-
# 6       12.0  SFr. 66,- / approx. € 71,-
# 7        6.0                      € 70,-
# 8       10.0                     € 69.50
# 9        4.0                      € 55,-
# 10       0.9                      € 67,-
# 11      39.0                      € 76,-
# 12      52.0                      € 79,-
# 13       2.7                      € 80,-
# 14       1.0                      € 70,-
# 15       4.8                      € 72,-
# 16      32.0                      € 79,-
# 17      13.0  SFr. 83,- / approx. € 89,-
# 18      18.0                      € 79,-
# 19      14.0                      € 65,-
#
#                                       local_name  \
# 0                                            NaN
# 1                             Stubaier Gletscher
# 2                                         Gröden
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                               Moos in Passeier
# 10  Ratschings-Jaufen)/​Malga Calice (Kalcheralm
# 11                                           NaN
# 12                                           NaN
# 13                                           NaN
# 14                                 Hochpustertal
# 15                                           NaN
# 16                                   Mountopolis
# 17                                           NaN
# 18                                     Skicircus
# 19                                           NaN
#
#                       sub_resorts             town_clean country_code  \
# 0                             NaN            Tauplitzalm           AT
# 1                             NaN  Neustift im Stubaital           AT
# 2                             NaN             St. Ulrich           IT
# 3                             NaN               Meransen           IT
# 4                             NaN              Obereggen           IT
# 5                             NaN                Lermoos           AT
# 6                             NaN             Bettmeralp           CH
# 7                             NaN                 Matrei           AT
# 8                             NaN             Neukirchen           AT
# 9                             NaN               Pfelders           IT
# 10                            NaN                  Bichl           IT
# 11                            NaN                 Ellmau           AT
# 12                            NaN                 Ischgl           AT
# 13                            NaN                  Fügen           AT
# 14                     Thurntaler                Sillian           AT
# 15                            NaN               Karersee           IT
# 16  Penken/Ahorn/Rastkogel/Eggalm              Mayrhofen           AT
# 17                            NaN                 Wengen           CH
# 18                            NaN               Saalbach           AT
# 19                            NaN                Nauders           AT
#
#     lift_price_eur  price_per_km_eur  difficulty_score elevation_band
# 0             59.0              1.36             1.713         Medium
# 1             72.5              1.12             1.446           High
# 2             80.0              0.44             1.829           High
# 3             70.0              1.27             1.833           High
# 4             71.0              1.45             1.951         Medium
# 5             68.0              2.57             1.528         Medium
# 6             71.0              0.68             1.712         Medium
# 7             70.0              1.75             1.938           High
# 8             69.5              0.93             1.667           High
# 9             55.0              3.06             1.944         Medium
# 10            67.0              2.38             1.833            Low
# 11            76.0              0.28             1.724           High
# 12            79.0              0.33             2.021           High
# 13            80.0              3.90             1.849           High
# 14            70.0              3.12             1.808           High
# 15            72.0              1.80             1.645         Medium
# 16            79.0              0.56             1.915      Very High
# 17            89.0              0.88             1.802           High
# 18            79.0              0.29             1.548           High
# 19            65.0              0.87             1.853           High

# %%
#fix resort names and create sub_resorts column
cleaned_name = (
    df["resort_name"]
    .str.replace(r"^\d+\.\s*", "", regex=True)
    .str.replace("\u200b", "", regex=False)
    .str.replace(r"\s+", " ", regex=True)
    .str.strip()
)

df[["resort_name", "sub_resorts"]] = (cleaned_name.str.split("–", n=1, expand=True))
df["resort_name"] = df["resort_name"].str.strip()
df["sub_resorts"] = df["sub_resorts"].str.strip()

# %%
#handle some missing data
df["sub_resorts"] = df["sub_resorts"].fillna("None")
df["weather_desc"] = df["weather_desc"].fillna("Unknown")
df["snow_mm"] = df["snow_mm"].fillna(0)

# %%
#extract lift price in euros as float
df["lift_price_eur"] = (
    df["lift_price"]
    .str.replace(",", ".")
    .str.extract(r"€\s*(\d+(\.\d+)?)")[0]
    .astype(float)
)

# %%
#calculate price per km
df["price_per_km_eur"] = (df["lift_price_eur"] / df["total_km"]).round(2)

# %%
#calculate difficulty score
df["difficulty_score"] = ((df["blue_km"] * 1 + df["red_km"] * 2 + df["black_km"] * 3) / df["total_km"]).round(3)   

#save cleaned data
df.to_csv(output_path, index=False)

# %%
df[9:12]
# Out:
#                                           resort_name  country  \
# 9   Saalbach Hinterglemm Leogang Fieberbrunn (Skic...  Austria
# 10                                   Le Grand Massif    France
# 11                                     Big Sky Resort      USA
#
#                         town  elevation_m  total_km  blue_km  red_km  \
# 9                   Saalbach       1266.0     270.0    140.0   112.0
# 10      Morillon-Les Esserts       1783.0     265.0    135.0    95.0
# 11  Big Sky Mountain Village       1330.0     250.0     53.0   150.0
#
#     black_km                   lift_price   latitude   longitude  temp_day  \
# 9       18.0                       € 79,-  47.391459   12.636447     -0.63
# 10      35.0                       € 61,-        NaN         NaN       NaN
# 11      47.0  US$ 285,- / approx. € 243,-  45.288217 -111.394108     -7.13
#
#     snow_mm weather_desc                               sub_resorts  \
# 9      0.68         snow                                      None
# 10     0.00      Unknown   Flaine/Les Carroz/Morillon/Samoëns/Sixt
# 11     0.00   few clouds                                      None
#
#     lift_price_eur  price_per_km_eur  difficulty_score
# 9             79.0              0.29             1.548
# 10            61.0              0.23             1.623
# 11           243.0              0.97             1.976

# %%
final_df = pd.read_csv("../data/ski_resorts_weather.csv")

# %%
final_df.head(30)
#final_df.info()
# Out:
#                                           resort_name      country  \
# 0                                       Les 3 Vallées       France
# 1                                Les Portes du Soleil  Switzerland
# 2                                           4 Vallées  Switzerland
# 3                                          Via Lattea        Italy
# 4               Zermatt/Breuil-Cervinia/Valtournenche  Switzerland
# 5                                        Les Sybelles       France
# 6                                  Tignes/Val d'Isère       France
# 7   St. Anton/St. Christoph/Stuben/Lech/Zürs/Warth...      Austria
# 8                     SkiWelt Wilder Kaiser-Brixental      Austria
# 9   Saalbach Hinterglemm Leogang Fieberbrunn (Skic...      Austria
# 10                                    Le Grand Massif       France
# 11                                     Big Sky Resort          USA
# 12                                          Park City          USA
# 13                                    Serre Chevalier       France
# 14                                        Alpe d'Huez       France
# 15                                     Ischgl/Samnaun      Austria
# 16                                           Snowmass          USA
# 17                                               Vail          USA
# 18                                  Arosa Lenzerheide  Switzerland
# 19                              La Plagne (Paradiski)       France
# 20                                        Grandvalira      Andorra
# 21                                        Deer Valley          USA
# 22                                 Whistler Blackcomb       Canada
# 23                                    Palisades Tahoe          USA
# 24                                        Les 2 Alpes       France
# 25              Les Arcs/Peisey-Vallandry (Paradiski)       France
# 26                                     Espace Diamant       France
# 27                                            KitzSki      Austria
# 28                                 Serfaus-Fiss-Ladis      Austria
# 29                               Megève/Saint-Gervais       France
#
#                               town  elevation_m  total_km  blue_km  red_km  \
# 0                 Méribel-Mottaret       2130.0     600.0    336.0   204.0
# 1                          Avoriaz       1269.0     580.0    310.0   210.0
# 2                          Verbier       1980.0     412.0    107.0   202.0
# 3                        Sestriere       1251.0     400.0     96.0   220.0
# 4                          Zermatt       2337.0     322.0     75.0   220.0
# 5                       Le Corbier       1520.0     310.0     71.3   217.0
# 6                    Tignes le Lac       1906.0     300.0    165.0    75.0
# 7             St. Anton am Arlberg       1507.0     299.7    130.0   120.0
# 8                           Ellmau       1249.0     275.0    115.0   121.0
# 9                         Saalbach       1266.0     270.0    140.0   112.0
# 10            Morillon-Les Esserts       1783.0     265.0    135.0    95.0
# 11        Big Sky Mountain Village       1330.0     250.0     53.0   150.0
# 12                       Park City        975.0     250.0     20.0   105.0
# 13                     Chantemerle       1600.0     250.0    137.5    80.0
# 14                     Alpe d'Huez       2205.0     250.0     70.0   130.0
# 15                          Ischgl       1512.0     239.0     47.0   140.0
# 16                Snowmass Village       1340.0     237.0     12.0   114.0
# 17                            Vail       1070.0     234.0     57.0    84.0
# 18                           Arosa       1636.0     225.0    110.0    87.0
# 19                   Plagne Centre       1960.0     225.0    139.0    59.0
# 20                         Canillo        930.0     215.0    100.0    82.0
# 21                       Park City        933.0     202.0     72.0    90.0
# 22                        Whistler       1609.0     200.0     40.0   110.0
# 23  The Village at Palisades Tahoe        855.0     200.0     50.0    85.0
# 24                  Les Deux Alpes       2243.0     200.0    110.0    56.0
# 25                        Arc 1600       2026.0     200.0    104.0    70.0
# 26                     Les Saisies       1069.0     192.0    132.0    49.0
# 27                       Kitzbühel       1200.0     188.0    102.0    66.0
# 28                         Serfaus       1628.0     186.0     47.0   112.0
# 29                          Megève       1503.0     185.0     70.0    90.0
#
#     black_km                    lift_price  \
# 0       60.0                       € 81.80
# 1       60.0                        € 72,-
# 2      103.0   SFr. 94,- / approx. € 101,-
# 3       84.0                        € 66,-
# 4       27.0  SFr. 116,- / approx. € 125,-
# 5       21.7                       € 59.30
# 6       60.0                        € 75,-
# 7       49.7                       € 81.50
# 8       39.0                        € 76,-
# 9       18.0                        € 79,-
# 10      35.0                        € 61,-
# 11      47.0   US$ 285,- / approx. € 243,-
# 12     125.0   US$ 351,- / approx. € 299,-
# 13      32.5                       € 65.50
# 14      50.0                        € 66,-
# 15      52.0                        € 79,-
# 16     111.0   US$ 279,- / approx. € 237,-
# 17      93.0   US$ 356,- / approx. € 303,-
# 18      28.0    SFr. 89,- / approx. € 96,-
# 19      27.0                        € 70,-
# 20      33.0                        € 69,-
# 21      40.0   US$ 349,- / approx. € 297,-
# 22      50.0    C$ 351,- / approx. € 218,-
# 23      65.0   US$ 290,- / approx. € 247,-
# 24      34.0                        € 66,-
# 25      26.0                        € 70,-
# 26      11.0                        € 50,-
# 27      20.0                       € 79.50
# 28      27.0                        € 78,-
# 29      25.0                       € 63.50
#
#                                           sub_resorts country_code  \
# 0         Val Thorens/Les Menuires/Méribel/Courchevel           FR
# 1    Morzine/Avoriaz/Les Gets/Châtel/Morgins/Champéry           CH
# 2           Verbier/La Tzoumaz/Nendaz/Veysonnaz/Thyon           CH
# 3   Sestriere/Sauze d’Oulx/San Sicario/Claviere/Mo...           IT
# 4                                          Matterhorn           CH
# 5   Le Corbier/La Toussuire/Les Bottières/St Colom...           FR
# 6                                                 NaN           FR
# 7                                         Ski Arlberg           AT
# 8                                                 NaN           AT
# 9                                                 NaN           AT
# 10            Flaine/Les Carroz/Morillon/Samoëns/Sixt           FR
# 11                                                NaN           US
# 12                                                NaN           US
# 13  Briançon/Chantemerle/Villeneuve-la-Salle/Le Mo...           FR
# 14                                                NaN           FR
# 15                                    Silvretta Arena           AT
# 16                                                NaN           US
# 17                                                NaN           US
# 18                                                NaN           CH
# 19                                                NaN           FR
# 20  Pas de la Casa/Grau Roig/Soldeu/El Tarter/Cani...           AD
# 21                                                NaN           US
# 22                                                NaN           CA
# 23                                                NaN           US
# 24                                                NaN           FR
# 25                                                NaN           FR
# 26  Les Saisies/Notre-Dame-de-Bellecombe/Praz sur ...           FR
# 27                                Kitzbühel/Kirchberg           AT
# 28                                                NaN           AT
# 29                                                NaN           FR
#
#     lift_price_eur  price_per_km_eur  difficulty_score   latitude   longitude  \
# 0             81.8              0.14             1.540  45.416466    6.565061
# 1             72.0              0.12             1.569        NaN         NaN
# 2            101.0              0.25             1.990  46.096101    7.228676
# 3             66.0              0.16             1.970  44.958453    6.878685
# 4            125.0              0.39             1.851  46.021208    7.749254
# 5             59.3              0.19             1.840  48.841004    3.357125
# 6             75.0              0.25             1.650  45.469729    6.907594
# 7             81.5              0.27             1.732  47.128900   10.266367
# 8             76.0              0.28             1.724  47.519272   12.292248
# 9             79.0              0.29             1.548  47.391459   12.636447
# 10            61.0              0.23             1.623  46.083821    6.677273
# 11           243.0              0.97             1.976  45.288217 -111.394108
# 12           299.0              1.20             2.420  40.646092 -111.497996
# 13            65.5              0.26             1.580  48.611570    3.659270
# 14            66.0              0.26             1.920  45.092401    6.069944
# 15            79.0              0.33             2.021  46.986282   10.274518
# 16           237.0              1.00             2.418  39.213042 -106.937821
# 17           303.0              1.29             2.154  39.643803 -106.388823
# 18            96.0              0.43             1.636  46.779725    9.678136
# 19            70.0              0.31             1.502  45.505878    6.674365
# 20            69.0              0.32             1.688  42.566831    1.597765
# 21           297.0              1.47             1.842  40.646092 -111.497996
# 22           218.0              1.09             2.050  50.117190 -122.954302
# 23           247.0              1.24             2.075        NaN         NaN
# 24            66.0              0.33             1.620  45.009995    6.123761
# 25            70.0              0.35             1.610  47.345057    5.189397
# 26            50.0              0.26             1.370  45.757330    6.539447
# 27            79.5              0.42             1.564  47.446359   12.391147
# 28            78.0              0.42             1.892  47.028411   10.559693
# 29            63.5              0.34             1.757  45.856709    6.617932
#
#               geocode_source  total_snowfall_30d_mm  avg_snow_depth_30d_mm  \
# 0                    Méribel                  32.90               0.059032
# 1                  not_found                    NaN                    NaN
# 2                    Verbier                  20.16               0.207419
# 3                  Sestriere                  28.14               0.023226
# 4                    Zermatt                  10.92               0.321613
# 5                 Le Corbier                   5.67               0.002258
# 6              Tignes le Lac                  58.66               0.947419
# 7       St. Anton am Arlberg                  26.60               0.160000
# 8                     Ellmau                  11.27               0.033226
# 9                   Saalbach                  31.85               0.040968
# 10                  Morillon                   9.87               0.000323
# 11  Big Sky Mountain Village                   6.93               0.028387
# 12                 Park City                  19.60               0.038065
# 13               Chantemerle                   6.30               0.000968
# 14               Alpe d'Huez                  47.95               0.070000
# 15                    Ischgl                  29.47               0.472903
# 16          Snowmass Village                   6.02               0.047742
# 17                      Vail                   4.55               0.016129
# 18                     Arosa                  20.30               0.163226
# 19             Plagne Centre                  45.57               0.495806
# 20                   Canillo                  18.20               0.124839
# 21                 Park City                  19.60               0.038065
# 22                  Whistler                  84.21               0.289677
# 23                 not_found                    NaN                    NaN
# 24            Les Deux Alpes                  47.67               0.027419
# 25                       Arc                   2.24               0.000000
# 26               Les Saisies                  56.84               0.202258
# 27                 Kitzbühel                  10.50               0.036129
# 28                   Serfaus                  14.14               0.284839
# 29                    Megève                  29.47               0.043871
#
#     avg_max_temp_30d_c
# 0         3.154839e+00
# 1                  NaN
# 2         2.464516e+00
# 3         9.032258e-02
# 4         3.077419e+00
# 5         5.390323e+00
# 6        -1.767742e+00
# 7         2.370968e+00
# 8         2.635484e+00
# 9         2.638710e+00
# 10        5.464516e+00
# 11        1.648387e+00
# 12        4.954839e+00
# 13        5.138710e+00
# 14        2.545161e+00
# 15       -2.387097e+00
# 16        4.238710e+00
# 17        5.748387e+00
# 18        6.709677e-01
# 19       -1.741935e-01
# 20        3.906452e+00
# 21        4.954839e+00
# 22        2.900000e+00
# 23                 NaN
# 24        3.477419e+00
# 25        4.561290e+00
# 26        1.587097e+00
# 27        2.390323e+00
# 28       -3.402296e-17
# 29        4.325806e+00
